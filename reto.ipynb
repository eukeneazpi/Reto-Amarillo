# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
df2020 = pd.read_excel('2020.xlsx')
df2021 = pd.read_excel('2021.xlsx')
df2022 = pd.read_excel('2022.xlsx')

# %%
df2020.isna().sum()
# Out:
# Unnamed: 0.1                                                 0
# Unnamed: 0                                                   0
# Nombre                                                       0
# Código NIF                                                   0
# Localidad                                                    1
# Provincia                                                    0
# País                                                         0
# Código primario CNAE 2009                                    0
# Literal código CNAE 2009 primario                            0
# Fecha constitución                                          14
# Importador / Exportador                                      0
# Países importación                                       37027
# Países exportación                                       38504
# Otros activos líquidos\nmil EUR\n2020                        0
# Inmovilizado\nmil EUR\n2020                                  0
# ...

# %%
df2020.shape
# Out:
# (39472, 55)

# %%
df2020.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           1
# 1             1           2
# 2             2           3
# 3             3           4
# 4             4           5
#
#                                               Nombre Código NIF Localidad  \
# 0               PETROLEOS DEL NORTE SOCIEDAD ANONIMA  A48053243    MUSKIZ
# 1                      SIDENOR ACEROS ESPECIALES SLU  B01292903   BASAURI
# 2  BRIDGESTONE HISPANIA MANUFACTURING SOCIEDAD LI...  B95922688   BASAURI
# 3  COMPAÑIA NORTEÑA DE BEBIDAS GASEOSAS NORBEGA S...  B48023030  GALDAKAO
# 4    BAHIA DE BIZKAIA ELECTRICIDAD SOCIEDAD LIMITADA  B48969877  ZIERBENA
#
#   Provincia    País  Código primario CNAE 2009  \
# 0   Vizcaya  ESPANA                       1920
# 1   Vizcaya  ESPANA                       2410
# 2   Vizcaya  ESPANA                       2211
# 3   Vizcaya  ESPANA                       1107
# 4   Vizcaya  ESPANA                       3519
#
# ...

# %%
df2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39472 entries, 0 to 39471
# Data columns (total 55 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Unnamed: 0.1                                         39472 non-null  int64
#  1   Unnamed: 0                                           39472 non-null  int64
#  2   Nombre                                               39472 non-null  object
#  3   Código NIF                                           39472 non-null  object
#  4   Localidad                                            39471 non-null  object
#  5   Provincia                                            39472 non-null  object
#  6   País                                                 39472 non-null  object
#  7   Código primario CNAE 2009                            39472 non-null  int64
# ...

# %%
list(df2020.columns)
# Out:
# ['Unnamed: 0.1',
#  'Unnamed: 0',
#  'Nombre',
#  'Código NIF',
#  'Localidad',
#  'Provincia',
#  'País',
#  'Código primario CNAE 2009',
#  'Literal código CNAE 2009 primario',
#  'Fecha constitución',
#  'Importador / Exportador',
#  'Países importación',
#  'Países exportación',
#  'Otros activos líquidos\nmil EUR\n2020',
#  'Inmovilizado\nmil EUR\n2020',
#  'Inmovilizado inmaterial\nmil EUR\n2020',
#  'Inmovilizado material\nmil EUR\n2020',
#  'Otros activos fijos\nmil EUR\n2020',
#  'Activo circulante\nmil EUR\n2020',
#  'Existencias\nmil EUR\n2020',
#  'Deudores\nmil EUR\n2020',
#  'Tesorería\nmil EUR\n2020',
#  'Total activo\nmil EUR\n2020',
#  'Capital suscrito\nmil EUR\n2020',
#  'Otros fondos propios\nmil EUR\n2020',
#  'Pasivo fijo\nmil EUR\n2020',
#  'Acreedores a L. P.\nmil EUR\n2020',
#  'Otros pasivos fijos\nmil EUR\n2020',
#  'Pasivo líquido\nmil EUR\n2020',
#  'Deudas financieras\nmil EUR\n2020',
#  'Acreedores comerciales\nmil EUR\n2020',
# ...

# %%
import numpy as np
df2020.replace('n.d.', np.NaN, inplace=True)
df2020.replace('Financial Export limit reached', np.NaN, inplace=True)

# %%
columnas = ['Nombre', 'Localidad', 'Código NIF', 'Provincia', 'País', 'Código primario CNAE 2009', 'Literal código CNAE 2009 primario', 'Fecha constitución', 'Importador / Exportador', 'Países importación', 'Países exportación']
for i, columna in enumerate(df2020.columns):
    if columna not in columnas:
        column = df2020.columns[i]
        df2020[column].astype(float)

df2020.dtypes
# Out:
# Unnamed: 0.1                                               int64
# Unnamed: 0                                                 int64
# Nombre                                                    object
# Código NIF                                                object
# Localidad                                                 object
# Provincia                                                 object
# País                                                      object
# Código primario CNAE 2009                                  int64
# Literal código CNAE 2009 primario                         object
# Fecha constitución                                        object
# Importador / Exportador                                   object
# Países importación                                        object
# Países exportación                                        object
# Otros activos líquidos\nmil EUR\n2020                    float64
# ...

# %%
df2021.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Nombre', 'Código NIF', 'Localidad',
#        'Provincia', 'País', 'Código primario CNAE 2009',
#        'Literal código CNAE 2009 primario', 'Fecha constitución',
#        'Importador / Exportador', 'Países importación', 'Países exportación',
#        'Otros activos líquidos\nmil EUR\n2021', 'Inmovilizado\nmil EUR\n2021',
#        'Inmovilizado inmaterial\nmil EUR\n2021',
#        'Inmovilizado material\nmil EUR\n2021',
#        'Otros activos fijos\nmil EUR\n2021',
#        'Activo circulante\nmil EUR\n2021', 'Existencias\nmil EUR\n2021',
#        'Deudores\nmil EUR\n2021', 'Tesorería\nmil EUR\n2021',
#        'Total activo\nmil EUR\n2021', 'Capital suscrito\nmil EUR\n2021',
#        'Otros fondos propios\nmil EUR\n2021', 'Pasivo fijo\nmil EUR\n2021',
#        'Acreedores a L. P.\nmil EUR\n2021',
#        'Otros pasivos fijos\nmil EUR\n2021', 'Pasivo líquido\nmil EUR\n2021',
#        'Deudas financieras\nmil EUR\n2021',
# ...

# %%
# Merge DataFrames on the 'ID' column
merged_df = pd.merge(df2020, df2021, on='Código NIF')

# Drop duplicated columns
merged_df = merged_df.loc[:, ~merged_df.columns.duplicated()]

print(merged_df)
# Out:
#        Unnamed: 0.1_x  Unnamed: 0_x  \
# 0                   0             1
# 1                   1             2
# 2                   2             3
# 3                   3             4
# 4                   4             5
# ...               ...           ...
# 40549            6016          6017
# 40550            6017          6018
# 40551            6018          6019
# 40552            6019          6020
# 40553            6020          6021
#
#                                          Nombre_x Código NIF      Localidad_x  \
# 0            IBERDROLA CLIENTES SOCIEDAD ANONIMA.  A95758389           BILBAO
# 1                         PAN AMERICAN ENERGY SL.  B88260203           BILBAO
# 2      IBERDROLA ENERGIA ESPAÑA SOCIEDAD ANONIMA.  A95758371           BILBAO
# 3                 ALVEAN SUGAR SOCIEDAD LIMITADA.  B95773057           BILBAO
# 4                     IBERDROLA, SOCIEDAD ANONIMA  A48010615           BILBAO
# ...

# %%
list(merged_df.columns)
# Out:
# ['Unnamed: 0.1_x',
#  'Unnamed: 0_x',
#  'Nombre_x',
#  'Código NIF',
#  'Localidad_x',
#  'Provincia_x',
#  'País_x',
#  'Código primario CNAE 2009_x',
#  'Literal código CNAE 2009 primario_x',
#  'Fecha constitución_x',
#  'Importador / Exportador_x',
#  'Países importación_x',
#  'Países exportación_x',
#  'Otros activos líquidos\nmil EUR\n2020',
#  'Inmovilizado\nmil EUR\n2020',
#  'Inmovilizado inmaterial\nmil EUR\n2020',
#  'Inmovilizado material\nmil EUR\n2020',
#  'Otros activos fijos\nmil EUR\n2020',
#  'Activo circulante\nmil EUR\n2020',
#  'Existencias\nmil EUR\n2020',
#  'Deudores\nmil EUR\n2020',
#  'Tesorería\nmil EUR\n2020',
#  'Total activo\nmil EUR\n2020',
#  'Capital suscrito\nmil EUR\n2020',
#  'Otros fondos propios\nmil EUR\n2020',
#  'Pasivo fijo\nmil EUR\n2020',
#  'Acreedores a L. P.\nmil EUR\n2020',
#  'Otros pasivos fijos\nmil EUR\n2020',
#  'Pasivo líquido\nmil EUR\n2020',
#  'Deudas financieras\nmil EUR\n2020',
#  'Acreedores comerciales\nmil EUR\n2020',
# ...
